# %%
import pandas as pd

dfCityTop20 = pd.read_csv("/Users/zacharywong/github/zacharywong2023/Top20byUSCity.csv")

dfUSTop20 = pd.read_csv("/Users/zacharywong/github/zacharywong2023/Top20inUS.csv")

dfCityTop20
# Out:
#                                  Song Name  \
# 0                    love nwantiti [Remix]
# 1                  Cold Heart (PNAU Remix)
# 2                                   Chosen
# 3                                    Pepas
# 4                                 I Hate U
# 5                        We Set The Trends
# 6                             Need To Know
# 7                    Smokin Out The Window
# 8                            Hello It's Me
# 9                              Do It to It
# 10                              Big Energy
# 11                         Essence [Mixed]
# 12                Love Nwantiti (Ah Ah Ah)
# 13                                 Shivers
# 14                  Ameno Amapiano (Remix)
# 15                                 abcdefu
# 16                      Pope Is A Rockstar
# 17                     Own Brand Freestyle
# 18                                  Beggin
# 19     love nwantiti (North African Remix)
# 20                               Hurricane
# ...

# %%
# Set indexes on the City Chart dataframe to Song Name
dfCityTop20 = dfCityTop20.set_index(['Song Name', 'Artist'])
dfCityTop20
# Out:
#                                                                                            New York City  \
# Song Name                              Artist
# love nwantiti [Remix]                  CKay Feat. Axel & Dj Yo!                                      1.0
# Cold Heart (PNAU Remix)                Elton John & Dua Lipa                                         2.0
# Chosen                                 Blxst & Tyga Feat. Ty Dolla $ign                              3.0
# Pepas                                  Farruko                                                       4.0
# I Hate U                               SZA                                                           5.0
# We Set The Trends                      Jim Jones & Migos                                             6.0
# Need To Know                           Doja Cat                                                      7.0
# ...

# %%
# Set indexes on the USTop20 DataFrame to Song Name 

dfUSTop20 = dfUSTop20.set_index(['Song Name', 'Artist'])
dfUSTop20
# Out:
#                                                                                 Rank in USTop20 Chart
# Song Name                              Artist
# The Cowboy In Me (Yellowstone Edition) Tim McGraw                                                   1
# Cold Heart (PNAU Remix)                Elton John & Dua Lipa                                        2
# Big Energy                             Latto                                                        3
# Super Gremlin                          Kodak Black                                                  4
# Pope Is A Rockstar                     SALES                                                        5
# Scorpio                                Moneybagg Yo                                                 6
# Shivers                                Ed Sheeran                                                   7
# Smokin Out The Window                  Bruno Mars, Anderson .Paak & Silk Sonic                      8
# ...

# %%
df = pd.concat([dfUSTop20, dfCityTop20], axis=1)
df
# Out:
#                                                                                            Rank in USTop20 Chart  \
# Song Name                              Artist
# 323 Go Crazy                           DOM KENNEDY                                                           NaN
# Ameno Amapiano (Remix)                 Goya Menor & Nektunez                                                 NaN
# Bad Habits                             Ed Sheeran                                                            NaN
# Beautiful Lies                         Yung Bleu & Kehlani                                                   NaN
# Beggin                                 Måneskin                                                             20.0
# Better Days                            NEIKED, Mae Muller & Polo G                                          13.0
# Big Energy                             Latto                                                                 3.0
# ...

# %%
df['Rank in USTop20 Chart']
# Out:
# Song Name                               Artist
# 323 Go Crazy                            DOM KENNEDY                                                 NaN
# Ameno Amapiano (Remix)                  Goya Menor & Nektunez                                       NaN
# Bad Habits                              Ed Sheeran                                                  NaN
# Beautiful Lies                          Yung Bleu & Kehlani                                         NaN
# Beggin                                  Måneskin                                                   20.0
# Better Days                             NEIKED, Mae Muller & Polo G                                13.0
# Big Energy                              Latto                                                       3.0
# Big Subwoofer                           MOUNT WESTMORE, Snoop Dogg, Ice Cube, E-40 & Too $hort      NaN
# ...

# %%
df.to_csv('/Users/zacharywong/github/zacharywong2023/Top20inUSandCity.csv')
