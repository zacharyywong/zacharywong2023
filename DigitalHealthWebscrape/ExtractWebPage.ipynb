# %%
# This script extracts all the important text from the langing page of a webpage for analysis

import requests
from bs4 import BeautifulSoup as bs

url = 'https://springhealth.com/'
res = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
html_page = res.content
soup = bs(html_page, 'html.parser')
text = soup.find_all(text=True)
text
# Out:
# ['html',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' ',
#  ' This site is optimized with the Yoast SEO plugin v17.4 - https://yoast.com/wordpress/plugins/seo/ ',
#  ' ',
#  'Mental Healthcare That’s Right For You - Spring Health',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://springhealth.com/#website","url":"https://springhealth.com/","name":"Spring Health","description":"Mental healthcare that\\u2019s precisely right for you","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://springhealth.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://springhealth.com/#primaryimage","inLanguage":"en-US","url":"https://springhealth.com/wp-content/uploads/2020/07/SH_social_FB_2.png","contentUrl":"https://springhealth.com/wp-content/uploads/2020/07/SH_social_FB_2.png","width":1200,"height":630},{"@type":"WebPage","@id":"https://springhealth.com/#webpage","url":"https://springhealth.com/","name":"Mental Healthcare That\\u2019s Right For You - Spring Health","isPartOf":{"@id":"https://springhealth.com/#website"},"datePublished":"2019-06-03T17:06:57+00:00","dateModified":"2021-10-19T15:59:06+00:00","description":"Eliminating barriers to mental healthcare. Clinically-proven technology with world-class providers to deliver precisely what your employees need.","breadcrumb":{"@id":"https://springhealth.com/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://springhealth.com/"]}]},{"@type":"BreadcrumbList","@id":"https://springhealth.com/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home"}]}]}',
#  '\n',
#  ' / Yoast SEO plugin. ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  " body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-background-color{background-color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-background-color{background-color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-background-color{background-color: va ...
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' ',
#  ' Global site tag (gtag.js) - Google Analytics ',
#  '\n',
#  '\n',
#  "\r\nwindow.dataLayer = window.dataLayer || [];\r\nfunction gtag(){dataLayer.push(arguments);}\r\ngtag('js', new Date());\r\ngtag('config', 'UA-78783966-1');\r\n",
#  '\n',
#  ' Facebook Tag ',
#  '\n',
#  ' ',
#  ' End Facebook Tag ',
#  ' ',
#  ' Google Tag Manager ',
#  '\n',
#  "(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\r\nnew Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\r\n'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,'script','dataLayer','GTM-NXF3KZB');",
#  '\n',
#  ' End Google Tag Manager ',
#  ' ',
#  ' Hotjar Tracking Code for https://springhealth.com/ ',
#  '\n',
#  "\r\n(function(h,o,t,j,a,r){\r\nh.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};\r\nh._hjSettings={hjid:2685732,hjsv:6};\r\na=o.getElementsByTagName('head')[0];\r\nr=o.createElement('script');r.async=1;\r\nr.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;\r\na.appendChild(r);\r\n})(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');\r\n",
#  '\n',
#  ' Google Tag Manager (noscript) ',
#  '\n',
#  '\n',
#  ' End Google Tag Manager (noscript) ',
#  '\n',
#  ' .class_gwp_my_template_file { cursor:help; } ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' .why-choose-quotes .item img { margin: 20px auto 0; display: block; max-width: 200px; } .top-bar p a { color: #fff; transition: .5s; text-decoration: underline; } .top-bar p a:hover { color: #F5715D; } ',
#  '\n',
#  '\n',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Join our webinar on 3/22 – The Cost of Likes: How Employers Can Support Families Struggling with Social Media. ',
#  'Save your spot here',
#  '!',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'About',
#  ' ',
#  'Our Approach',
#  ' ',
#  ' ',
#  'EAP',
#  ' ',
#  'Digital CBT',
#  ' ',
#  'Consultants',
#  ' ',
#  ' ',
#  ' ',
#  'Providers',
#  ' ',
#  'Blog',
#  ' ',
#  ' ',
#  ' ',
#  'Member Log In',
#  ' ',
#  'Request Demo',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Hero Home',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Personalized ',
#  'mental healthcare',
#  ' ',
#  ' for your whole team.',
#  ' ',
#  'Enhance or replace your EAP with the most holistic approach to employee wellbeing.',
#  ' ',
#  'Request Demo',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'credibility sec',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Trusted by Leading Employers',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' personalized support spectrum ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Unparalleled Personalization of Care',
#  ' ',
#  "We combine clinically-proven technology with high-touch care navigation to deliver the right care at the right time—whether that's a meditation program, therapy, or more.",
#  ' ',
#  ' ',
#  ' ',
#  'Davynn needs help with her...',
#  'Relationship Issues',
#  ' ',
#  'Dylan needs help with his...',
#  'Eating Disorder',
#  ' ',
#  'Liam needs help with his...',
#  'Burnout',
#  ' ',
#  'Grace needs help with her...',
#  'Social anxiety',
#  ' ',
#  'Pete needs help with his...',
#  'Financial stress',
#  ' ',
#  'Julian needs help with his...',
#  'Trauma',
#  ' ',
#  'Ray needs help with their...',
#  'Alcoholism',
#  ' ',
#  'Jane needs help with her...',
#  'Addiction',
#  ' ',
#  'Erika needs help with her...',
#  'Confidence',
#  ' ',
#  'Morgan needs help with her...',
#  'Sleep issues',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Subclinical',
#  ' ',
#  'Clinical',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Health Plan',
#  ' ',
#  'Mindfulness',
#  ' ',
#  'Meditation',
#  ' ',
#  'Insomnia',
#  'Solution',
#  ' ',
#  'Coaching',
#  ' ',
#  'Self-guided therapy',
#  ' ',
#  'Licensed therapist',
#  ' ',
#  'Medication Management',
#  ' ',
#  'Rehab',
#  ' ',
#  ' ',
#  ' ',
#  ' member experience ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'How it works',
#  ' ',
#  'The Best Mental Healthcare Experience',
#  ' ',
#  'We put our members first by providing fast, simplified access to a variety of mental health solutions ',
#  ' - all from one spot. Spring Health integrates with your benefits ecosystem for a more holistic, streamlined approach to your employee experience. ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'We listen to thoroughly understand',
#  'Spring Health delivers a comprehensive, clinically validated, and dynamic assessment to carefully understand what you’re looking for and what you’re dealing with—no matter where you sit on the spectrum of need.',
#  'We personalize their experience',
#  'Based on your responses, Spring Health uses Precision Mental Healthcare to identify precisely the right option for you.',
#  'We make it easy to access what they need',
#  '• Schedule directly with a therapist and see them tomorrow',
#  ' • Complete a mindfulness exercise instantly',
#  ' • Chat with a licensed mental health professional whenever, however',
#  "We're there every step of the way",
#  'Our platform and Care Navigators follow up to make sure Spring Health is working for you',
#  ' ',
#  ' ',
#  ' ',
#  ' member stories ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Member stories of transformation',
#  ' ',
#  'We change (and save) lives',
#  ' ',
#  ' ',
#  "High touch support that respects each person's individuality",
#  '"Therapy online is new for me, but Spring Health\'s structure, care navigation team, and check ins have helped me feel like I am getting the attention I would in a physical office."',
#  'Eliminate financial barriers to care',
#  ' "I have always wanted to try therapy but have never gotten a chance to. My insurance didn\'t cover any expenses, but Spring Health gave me the opportunity to try it out."',
#  'Deliver results and change lives',
#  ' "My confidence has improved and many of the issues that existed in our first session are nonexistent. My provider Gina at Spring Health has truly changed the course of my life."',
#  '30%',
#  'of all employees sign up for Spring Health',
#  ' ',
#  'Half a day',
#  'of recovered productivity per member per week',
#  ' ',
#  '70%',
#  'of care happens outside of business hours',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "How we're different",
#  ' ',
#  'Why employers choose Spring Health',
#  ' ',
#  ' ',
#  'xml version="1.0" encoding="UTF-8"?',
#  ' ',
#  ' ',
#  'Group 23',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Something for everyone',
#  'Our proprietary technology screens for over 10 mental health conditions, and uses data and machine-learning to match every individual to their own personalized care plan.',
#  ' ',
#  'xml version="1.0" encoding="UTF-8"?',
#  ' ',
#  ' ',
#  'Group 17',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'High-touch care navigation for every member',
#  'Navigating benefits and finding care should be easy. Our Care Navigators serve as guides to our members, providing emotional support, recommendations, and referrals to other benefits within your ecosystem.',
#  ' ',
#  'xml version="1.0" encoding="UTF-8"?',
#  ' ',
#  ' ',
#  'Group 29',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'The most diverse, high-quality network for your team',
#  'Our licensed Care Navigators are available through chat, email, video, and phone support.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "How we're different",
#  ' ',
#  "Triaging mental health needs with technology that hasn't been clinically validated can pose significant risks to employees.",
#  ' ',
#  'Learn more about Precision Mental Healthcare.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '"Love the assessment and getting matched with a professional who specializes in what you\'re looking for. I also love the Care Navigators who really make the process seamless.”',
#  ' ',
#  'Spring Health Member at TED Conferences',
#  'xml version="1.0" encoding="UTF-8"?',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '"MasterClass employees have been thrilled with the Spring Health benefit!"',
#  ' ',
#  'Jessica Simmons, People Operations Manager at Masterclass',
#  ' ',
#  '"SH is my favorite platform and resource for our employees. I am a huge fan of the utilization reports. Also, we have incredible support—shoutout to our partnership success manager!"',
#  ' ',
#  '- Ariana Whitson, HR Operations Specialist',
#  'xml version="1.0" encoding="utf-8"?',
#  ' ',
#  ' Generator: Adobe Illustrator 23.0.1, SVG Export Plug-In . SVG Version: 6.00 Build 0) ',
#  ' ',
#  '\n',
#  ' .st0{fill:#0599C5;} ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '"Easy to use, my employees LOVE this perk, and it is helping ease the pain of two major issues in mental healthcare—accessibility and affordability."',
#  ' ',
#  '- Ashley Redding Hall, People Operations Manager',
#  'xml version="1.0" encoding="UTF-8"?',
#  ' ',
#  ' ',
#  'Bitmap',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Customer Testimonials',
#  ' ',
#  'We make companies stronger',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '"[A] quickly growing company, where clients are seeing tremendous savings in mental healthcare claims, and greatly improved employee engagement and wellbeing at work."',
#  ' ',
#  '- Josh Bersin, world-renowned HR industry analyst',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Instacart',
#  ' recovered',
#  '730 hours',
#  'in productivity hours in one month',
#  'Learn how',
#  'MasterClass',
#  ' signed up',
#  '20%',
#  'in the first day of launching',
#  'Banfield',
#  ' achieved',
#  '$4.80 PEPM',
#  'savings in direct medical costs alone',
#  ' ',
#  ' ',
#  ' Learn More ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' latest blog posts ',
#  ' ',
#  ' ',
#  ' ',
#  'From the Blog',
#  ' ',
#  'The latest from Spring Health',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '3 Powerful Ways HR Leaders Can Elevate Black Mental Health',
#  ' ',
#  'Read more',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'How General Mills Is Embracing Mental Health',
#  ' ',
#  'Read more',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Spring Health Reaches $2B Valuation and Launches Family Mental Health Solution Globally',
#  ' ',
#  'Read more',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Read More',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' call to action ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  "Let's ",
#  'eliminate barriers',
#  ' to mental health for your team, ',
#  'together.',
#  ' ',
#  ' Request Demo ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' Footer Subscribe',
#  ' ',
#  ' ',
#  ' ',
#  'Sign up for ',
#  'Spring Health',
#  ' emails',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Footer',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Already a member?',
#  ' ',
#  'Sign in',
#  ' or ',
#  'sign up',
#  ' ',
#  'Want to join our provider network?',
#  ' ',
#  'Apply here',
#  ' ',
#  ' ',
#  ' ',
#  'About',
#  ' ',
#  'Our Approach',
#  ' ',
#  'Providers',
#  ' ',
#  'Blog',
#  ' ',
#  'Contact Us',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Contact',
#  ' ',
#  ' ',
#  'Questions about care',
#  '+1 (',
#  '855) 629 0554',
#  ' ',
#  'Suicidal Crisis',
#  '+1 (800) 273-8255 ',
#  ' ',
#  'Sales and partnerships',
#  'partnerships@springhealth.com',
#  ' ',
#  'Press',
#  'press@springhealth.com',
#  ' ',
#  'Careers',
#  'We’re hiring!',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '© 2021 Spring Care, Inc. All rights reserved.',
#  ' ',
#  'Terms of Use',
#  ' ',
#  'Privacy Policy',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  '\r\n(function(e,t,o,n,p,r,i){e.visitorGlobalObjectAlias=n;e[e.visitorGlobalObjectAlias]=e[e.visitorGlobalObjectAlias]||function(){(e[e.visitorGlobalObjectAlias].q=e[e.visitorGlobalObjectAlias].q||[]).push(arguments)};e[e.visitorGlobalObjectAlias].l=(new Date).getTime();r=t.createElement("script");r.src=o;r.async=true;i=t.getElementsByTagName("script")[0];i.parentNode.insertBefore(r,i)})(window,document,"https://diffuser-cdn.app-us1.com/diffuser/diffuser.js","vgo");\r\nvgo(\'setAccount\', \'223804783\');\r\nvgo(\'setTrackByDefault\', true);\r\nvgo(\'process\');\r\n',
#  '\n',
#  '\r\n_linkedin_partner_id = "2213569";\r\nwindow._linkedin_data_partner_ids = window._linkedin_data_partner_ids || [];\r\nwindow._linkedin_data_partner_ids.push(_linkedin_partner_id);\r\n',
#  '\n',
#  '\r\n(function(){var s = document.getElementsByTagName("script")[0];\r\nvar b = document.createElement("script");\r\nb.type = "text/javascript";b.async = true;\r\nb.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";\r\ns.parentNode.insertBefore(b, s);})();\r\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Spring Health uses cookies to provide you with a better browsing experience and personalize content.',
#  ' For a complete overview of all cookies used, please see our ',
#  'Privacy Policy',
#  ' ',
#  'Accept',
#  'X',
#  '\n',
#  '\n',
#  '\nvar springhealth_system = {"ajax_url":"https:\\/\\/springhealth.com\\/wp-admin\\/admin-ajax.php","activecampaign_form":{"#demo-form":"<h1 class=\\"text-center\\">Schedule a Demo<\\/h1>\\r\\n<script>\\r\\nhbspt.forms.create({\\r\\nportalId: \\"8056012\\",\\r\\nformId: \\"569d866d-4fd3-4c55-8545-cb5603fc624a\\",\\r\\ntarget: \'.popup-content\'\\t\\r\\n});\\r\\n<\\/script> ","#moments-form":"<h1 class=\\"text-center\\">Schedule a Demo<\\/h1>\\r\\n<script>\\r\\nhbspt.forms.create({\\r\\nportalId: \\"8056012\\",\\r\\nformId: \\"ef72200a-115f-4d84-b7ed-c1a80b1e287a\\",\\r\\ntarget: \'.popup-content\'\\t\\r\\n});\\r\\n<\\/script> ","#executive-form":"<div class=\\"_form_13\\"><\\/div><script src=\\"https:\\/\\/springhealth.activehosted.com\\/f\\/embed.php?id=13\\" type=\\"text\\/javascript\\" charset=\\"utf-8\\"><\\/script>","#eap-demo-form":"<h1 class=\\"text-center\\">Schedule a Demo<\\/h1>\\r\\n<script>\\r\\nhbspt.forms.create({\\r\\nportalId: \\"8056012\\",\\r\\nformId: \\"1b33886f-da34-42fe-be15-c0f42580f2c4\\",\\r\\ntarget: \'.popup-content\'\\t\\r\\n});\\r\\n<\\/script> ","#newsletter":"<h1 class=\\"text-center\\">Sign up for our Newsletter<\\/h1>\\r\\n<script>\\r\\nhbspt.forms.create({\\r\\nportalId: \\"8056012\\",\\r\\nformId: \\"046dabe2-89df-4fef-afcd-ad69ad32d5a8\\",\\r\\ntarget: \'.popup-content\'\\t\\r\\n});\\r\\n<\\/script>","#signup-emails":"<script>\\r\\nhbspt.forms.create({\\r\\nportalId: \\"8056012\\",\\r\\nformId: \\"046dabe2-89df-4fef-afcd-ad69ad32d5a8\\",\\r\\n target: \'.footer-signup-form\',\\r\\nsfdcCampaignId: \\"7015A000001PhFGQA0\\"\\r\\n});\\r\\n<\\/script>"}};\n',
#  '\n',
#  '\n',
#  '\n']

# %%
set([t.parent.name for t in text])
# Out:
# {'[document]',
#  'a',
#  'body',
#  'div',
#  'footer',
#  'g',
#  'h1',
#  'h2',
#  'h3',
#  'h4',
#  'header',
#  'html',
#  'img',
#  'li',
#  'link',
#  'meta',
#  'noscript',
#  'p',
#  'script',
#  'span',
#  'strong',
#  'style',
#  'svg',
#  'title',
#  'ul'}

# %%
ignore = ['[document]', 'a', 'article', 'label','div','script', 'style', 'title', 'img', 'svg', 'ul', 'g', 'footer', 'button', 'clippath', 'nav']
output = ''
for t in text:
    if t.parent.name not in ignore:
        output += '{} '.format(t)
output
# Out:
# '\n \n \n \n \n \n \n    This site is optimized with the Yoast SEO plugin v17.4 - https://yoast.com/wordpress/plugins/seo/    \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n  / Yoast SEO plugin.  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n    Global site tag (gtag.js) - Google Analytics  \n \n \n  Facebook Tag  \n    End Facebook Tag     Google Tag Manager  \n \n  End Google Tag Manager     Hotjar Tracking Code for https://springhealth.com/  \n \n  Google Tag Manager (noscript)  \n \n  End Google Tag Manager (noscript)  \n \n \n \n \n \n \n \n       Join our webinar on 3/22 – The Cost of Likes: How Employers Can Support Families Struggling with Social Media.  !           Hero Home   Personalized  mental healthcare    for your whole team. Enhance or replace your EAP with the most holistic approach to employee wellbeing.   credibility sec   Trusted by Leading Employers    personalized support spectrum    Unparalleled Personalization of Care We combine clinically-proven technology with high-touch care navigation to deliver the right care at the right time—whether that\'s a meditation program, therapy, or more. Davynn needs help with her... Relationship Issues Dylan needs help with his... Eating Disorder Liam needs help with his... Burnout Grace needs help with her... Social anxiety Pete needs help with his... Financial stress Julian needs help with his... Trauma Ray needs help with their... Alcoholism Jane needs help with her... Addiction Erika needs help with her... Confidence Morgan needs help with her... Sleep issues Subclinical Clinical Health Plan Mindfulness Meditation Insomnia Solution Coaching Self-guided therapy Licensed therapist Medication Management Rehab    member experience    How it works The Best Mental Healthcare Experience We put our members first by providing fast, simplified access to a variety of mental health solutions   - all from one spot. Spring Health integrates with your benefits ecosystem for a more holistic, streamlined approach to your employee experience.  We listen to thoroughly understand Spring Health delivers a comprehensive, clinically validated, and dynamic assessment to carefully understand what you’re looking for and what you’re dealing with—no matter where you sit on the spectrum of need. We personalize their experience Based on your responses, Spring Health uses Precision Mental Healthcare to identify precisely the right option for you. We make it easy to access what they need • Schedule directly with a therapist and see them tomorrow  • Complete a mindfulness exercise instantly  • Chat with a licensed mental health professional whenever, however We\'re there every step of the way Our platform and Care Navigators follow up to make sure Spring Health is working for you    member stories    Member stories of transformation We change (and save) lives High touch support that respects each person\'s individuality "Therapy online is new for me, but Spring Health\'s structure, care navigation team, and check ins have helped me feel like I am getting the attention I would in a physical office." Eliminate financial barriers to care  "I have always wanted to try therapy but have never gotten a chance to. My insurance didn\'t cover any expenses, but Spring Health gave me the opportunity to try it out." Deliver results and change lives  "My confidence has improved and many of the issues that existed in our first session are nonexistent. My provider Gina at Spring Health has truly changed the course of my life." 30% of all employees sign up for Spring Health Half a day of recovered productivity per member per week 70% of care happens outside of business hours   How we\'re different Why employers choose Spring Health Something for everyone Our proprietary technology screens for over 10 mental health conditions, and uses data and machine-learning to match every individual to their own personalized care plan. High-touch care navigation for every member Navigating benefits and finding care should ...

# %%
outputSub = output.split(' ')
outputSub

word = ''
if (word in outputSub or word.capitalize() in outputSub):
    print(word.capitalize())
else:
    print('word not there')
# Out:
# Customer
