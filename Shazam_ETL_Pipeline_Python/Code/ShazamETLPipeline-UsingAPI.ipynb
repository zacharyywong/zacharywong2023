# %%
# This program builds an ETL pipeline using Shazam data collected through an API to surface the most important songs of the day 
# Sends an automated email and auto-updates a Google Spreadsheet with results/dynamic graphs 
# Author: Zachary Wong
# 1/16/2022

#import data libraries
import pandas as pd
import numpy as np
from datetime import date, datetime
import pytz 
import requests 

# import libs, authorize gspread  
import gspread
from oauth2client.service_account import ServiceAccountCredentials
scope = [
   'https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
google_key_file = '/Users/zacharywong/Documents/ServiceAccountKey-Secret/pelagic-tracker-338302-eaf0e0e671cb.json'
credentials = ServiceAccountCredentials.from_json_keyfile_name(google_key_file, scope)
gc = gspread.authorize(credentials)

APIkey = ''
pathtoKey = '/Users/zacharywong/Documents/RapidAPIShazamKey/RapidAPIKey.txt'
with open (pathtoKey, 'r') as file:
    APIKey = file.read()

#import email libs
import email, ssl, smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from email.mime.base import MIMEBase

# relative path to dataframe folder
pathtoDFolder = '/Users/zacharywong/github/zacharywong2023/Shazam_ETL_Pipeline_Python/IntermediateDataFrames/'

# keep track of day/time 
est = pytz.timezone('US/Eastern')
fmt = '%d/%m/%Y %H:%M:%S'
now = datetime.now()
now = now.astimezone(est).strftime(fmt)
print("day/time: " + now)
# Out:
# day/time: 01/02/2022 20:41:24

# %%
# Helper function: reads in values from Top 5 Important Songs Google Sheets
# Need spreadsheet ID and the cell address where the value should be read in 
# returns the value 

def readinValue(spreadsheet_id, cellLocation):
    sh = gc.open_by_key(spreadsheet_id)
    worksheet = sh.get_worksheet(0)
    value = worksheet.acell(cellLocation).value
    return value

# %%
# Helper function: changes the cell value in the Top 5 Important Songs Google Sheets
# Need spreadsheet ID, the cell address where the value should in, and the value to read in 

def changeCellValue(spreadsheet_id, cellLocation, value):
    sh = gc.open_by_key(spreadsheet_id)
    worksheet = sh.get_worksheet(0)
    worksheet.update(cellLocation, value)

# %%
# Grab and store variables for the rest of the code 
# SongLimit: top n number of songs to be read from both national and city charts
# Max Song Limit is 50 because each city has a Top 50 song chart. 
# UnrankedSongChangedWeight: the increase/decrease in weight given to songs with rankings greater than SongLimit  

spreadsheet_id = '1WYvfPFW6n2hOCZ-2_pTT0hjJOj5vGHbwjLnjzDqXhSM'

# read in SongLimit value
# If user inputs songlimit more than 50, change it to 50 
cellLocationLimit = 'B10'
SongLimit = int(readinValue(spreadsheet_id, cellLocationLimit))
maxSongLimit = 20
if SongLimit > maxSongLimit: 
    SongLimit = maxSongLimit
    changeCellValue(spreadsheet_id, cellLocationLimit, maxSongLimit)

# read in unrankedSongChangedWeight
# if user inputs weight equal or less than 0, change weight to 1 
cellLocationWeight = 'B11'
UnrankedSongChangedWeight = int(readinValue(spreadsheet_id, cellLocationWeight))
minSongWeight = 1
if UnrankedSongChangedWeight < minSongWeight: 
    UnrankedSongChangedWeight = minSongWeight
    changeCellValue(spreadsheet_id, cellLocationWeight, minSongWeight)
    
print("SongLimit: "+ str(SongLimit) + ' ' + "UnrankedSongChangedWeight: " + str(UnrankedSongChangedWeight))
# Out:
# SongLimit: 20 UnrankedSongChangedWeight: 1

# %%
#Create two data frames that will be merged later 

dfUSTop20 = pd.DataFrame(columns=["Song Name","Artist","Rank in USTop20 Chart"])
dfCityTop20 = pd.DataFrame(columns=["Song Name","Artist"])
dfCityTop20

#Call API For list of countries and its cities

USCitiesURL= "https://shazam-core.p.rapidapi.com/v1/frame/cities"

headers = {
    'x-rapidapi-host': "shazam-core.p.rapidapi.com",
    'x-rapidapi-key': APIKey
    }

USCitiesResponse = requests.request("GET", USCitiesURL, headers = headers).json()

#Extract all cities from the US and put each list containing CityID, CityName into a list 
USCities = []
CityIndex = 0
NumberofCities = 202
while CityIndex != NumberofCities:
    CityIDName = []
    CityIDName.append(USCitiesResponse[9]['cities'][CityIndex]['id'])
    CityIDName.append(USCitiesResponse[9]['cities'][CityIndex]['name'])
    USCities.append(CityIDName)
    CityIndex = CityIndex + 1

USCities[0:5]
# Out:
# [['5128581', 'New York City'],
#  ['5368361', 'Los Angeles'],
#  ['4887398', 'Chicago'],
#  ['4699066', 'Houston'],
#  ['4180439', 'Atlanta']]

# %%
# A Helper Function to fill in Song Rankings in the dfCityTop20 dataframe 

def updateSongRank(SongListResponse, SongIndex, dfCityTop20, SongLimit):
    
    #Append top 20 songs to the CityTop20 Dataframe 
    SongRank = 0
    while SongRank < SongLimit: 
        SongName = SongListResponse[SongRank]['title']
        SongArtist = SongListResponse[SongRank]['subtitle']
        
        # append new song/artist to dataframe if not already inside 
        if SongName not in dfCityTop20['Song Name'].unique():
            dfCityTop20 = dfCityTop20.append({"Song Name": SongName, "Artist": SongArtist}, ignore_index = True)
            global SongIndexCounter
            SongIndex.update({SongName: SongIndexCounter})  
            SongIndexCounter += 1
            #print(SongName)
            
        # fill in the value (rank) for the song for the specific city if not the same as previous day
        # update rank for next song
        if (dfCityTop20.at[SongIndex.get(SongName), CityName] != SongRank+1):
            dfCityTop20.at[SongIndex.get(SongName), CityName] = SongRank+1
        SongRank += 1
        
    #print(SongIndex)
    #Reset song rank
    return dfCityTop20

# %%
# API Call for Top20 Songs for first 20 cities 
CityChartURL = "https://shazam-core.p.rapidapi.com/v1/charts/city"

headers = {
    'x-rapidapi-host': "shazam-core.p.rapidapi.com",
    'x-rapidapi-key': APIKey
    }

maxCityLimit = 20
for CityIndex in range(0, maxCityLimit):
    dfCityTop20[USCities[CityIndex][1]] = None 
    
dfCityTop20

# Fill in the CityTop20 Dataframe for first 20 cities in the list 
# Only use first 20 cities to limit the number of API Calls for this assignment 

SongLimit = 20
CityIndex = 0

# Keeps track of the song and its index in the dfCityTop20 dataframe 
SongIndex = {}
SongIndexCounter = 0

# Loop through each city 
for CityIndex in range(0, 20): 
    
    # extract the cityID and City Name for this city
    CityID = USCities[CityIndex][0]
    CityName = USCities[CityIndex][1]
        
    # API Call to get the top20 Shazam Chart for the city and call helper function to fill in song rankings  
    querystring = {"city_id":CityID,"limit": SongLimit}
    SongListResponse= requests.request("GET", CityChartURL, headers=headers, params=querystring).json()
    dfCityTop20 = updateSongRank(SongListResponse, SongIndex, dfCityTop20, SongLimit)
    
    #update City Index 
    CityIndex = CityIndex + 1

dfCityTop20
# Out:
#                                             Song Name  \
# 0                                     I Lied (Part 1)
# 1                                Drink Before The War
# 2                             Cold Heart (PNAU Remix)
# 3                                            I Hate U
# 4                                         TO THE MOON
# 5              Ameno Amapiano Remix (You Wanna Bamba)
# 6                                      Here In Spirit
# 7                                                Peru
# 8                                         Hrs and Hrs
# 9                                       Super Gremlin
# 10                                 Ginseng Strip 2002
# 11                                Never Tear Us Apart
# 12  Watercolor Eyes (From “Euphoria” An HBO Origin...
# 13                              love nwantiti [Remix]
# 14                                        I Look Good
# 15                                  Ca Plane Pour Moi
# 16                                         Heat Waves
# 17                                         Big Energy
# 18                                    Fingers Crossed
# 19                                             Chosen
# 20                                   I Like Me Better
# 21                                               Eazy
# 22                                              Pepas
# 23                                Meet Me At Our Spot
# 24           Sometimes I Feel Like A Motherless Child
# 25                                      Chaise Longue
# 26                                Right Down The Line
# 27                                             Rumors
# 28                                        Better Days
# 29                                           Pressure
# 30                                              a Lot
# 31                      "R.A.P. Music" Album Untitled
# 32                                 Knife Talk [Mixed]
# 33                                            Scorpio
# 34                                         Easy On Me
# 35                                            abcdefu
# 36                                   El Incomprendido
# 37                                          Me or Sum
# 38                                           pushin P
# 39                                          Pop Music
# 40                                     Beautiful Lies
# 41                                            Shivers
# 42                                        Do It to It
# 43                           Love Nwantiti (Ah Ah Ah)
# 44                                      One Right Now
# 45                                          Oh My God
# 46                                       Need To Know
# 47                                  THATS WHAT I WANT
# 48                                            Beggin'
# 49                     Big Subwoofer (Single Version)
# 50                                        For Tonight
# 51                                      Brooklyn Love
# 52                                          Breakdown
# 53                                              Ghost
#
#                                                Artist New York City  \
# 0                                        Scribz Riley             1
# 1                                     Sinéad O'Connor             2
# 2                               Elton John & Dua Lipa             3
# 3                                                 SZA             4
# 4                                            Jnr Choi             5
# 5                               Goya Menor & Nektunez             6
# 6                                           Jim James             7
# 7                            Fireboy DML & Ed Sheeran             8
# 8                                           Muni Long             9
# 9                                         Kodak Black            10
# 10                                          Yung Lean            11
# 11                                               INXS            12
# 12                                       Lana Del Rey            13
# 13                           CKay Feat. Axel & Dj Yo!            14
# 14                                       O.T. Genasis            15
# 15                                   Plastic Bertrand            16
# 16                                      Glass Animals            17
# 17                                              Latto            18
# 18                               Lauren Spencer-Smith            19
# 19                   Blxst & Tyga Feat. Ty Dolla $ign            20
# 20                                               Lauv           NaN
# 21                              The Game & Kanye West           NaN
# 22                                            Farruko           NaN
# 23                   THE ANXIETY, WILLOW & Tyler Cole           NaN
# 24                                    Mahalia Jackson           NaN
# 25                                            Wet Leg           NaN
# 26                                     Gerry Rafferty           NaN
# 27                          Gucci Mane Feat. Lil Durk           NaN
# 28                   NEIKED & Mae Muller Feat. Polo G           NaN
# 29                                         Ari Lennox           NaN
# 30                                          21 Savage           NaN
# 31                                        Killer Mike           NaN
# 32                Drake Feat. 21 Savage & Project Pat           NaN
# 33                                       Moneybagg Yo           NaN
# 34                                              Adele           NaN
# 35                                              GAYLE           NaN
# 36                Farruko, Victor Cardenas & Dj Adoni           NaN
# 37                 Nardo Wick Feat. Future & Lil Baby           NaN
# 38                    Gunna & Future Feat. Young Thug           NaN
# 39             2 Chainz Feat. Moneybagg Yo & Beatking           NaN
# 40                                Yung Bleu & Kehlani           NaN
# 41                                         Ed Sheeran           NaN
# 42                               Acraze Feat. Cherish           NaN
# 43                                               CKay           NaN
# 44                           Post Malone & The Weeknd           NaN
# 45                                              Adele           NaN
# 46                                           Doja Cat           NaN
# 47                                          Lil Nas X           NaN
# 48                                           Måneskin           NaN
# 49  MOUNT WESTMORE, Snoop Dogg, Ice Cube, E-40 & T...           NaN
# 50                                             GIVĒON           NaN
# 51                                         Lolo Zouaï           NaN
# 52                      Tom Petty & The Heartbreakers           NaN
# 53                                      Justin Bieber           NaN
#
#    Los Angeles Chicago Houston Atlanta Dallas Miami Phoenix  ... Philadelphia  \
# 0            8       2       2       1      2     3      18  ...            1
# 1            1       1       1       2      1     2       1  ...            2
# 2            7       8      10     NaN     11     1       4  ...           11
# 3          NaN      20     NaN      10     12   NaN     NaN  ...            9
# 4          NaN     NaN     NaN     NaN    NaN     9     NaN  ...          NaN
# 5          NaN     NaN     NaN      13    NaN    10     NaN  ...          NaN
# 6            6       3       7       4      5    12       7  ...            3
# 7          NaN     NaN     NaN      16    NaN    11     NaN  ...            6
# 8          NaN       4       6       3      6     5     NaN  ...            4
# 9           16      11       4       5      4     8       9  ...            7
# 10           4       5       3       8      3     7       2  ...           13
# 11           9      18      18     NaN    NaN   NaN     NaN  ...           16
# 12           5      13      11      19     13   NaN      17  ...           14
# 13         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 14          10      10      14       7      7    17       5  ...            5
# 15          11       9     NaN     NaN     15   NaN     NaN  ...           12
# 16          13      17      13     NaN      8    13      10  ...           19
# 17           3      16       9      15     10    14       3  ...            8
# 18          14       7      20     NaN    NaN   NaN      12  ...           15
# 19         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 20           2     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 21          12     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 22          15     NaN      12     NaN     20     4      15  ...          NaN
# 23          17     NaN     NaN     NaN    NaN   NaN      19  ...          NaN
# 24          18     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 25          19     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 26          20     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 27         NaN       6     NaN      17    NaN   NaN     NaN  ...           17
# 28         NaN      12     NaN     NaN    NaN   NaN      13  ...          NaN
# 29         NaN      14      16       6    NaN   NaN     NaN  ...           10
# 30         NaN      15     NaN     NaN     19   NaN     NaN  ...          NaN
# 31         NaN      19     NaN     NaN     17   NaN     NaN  ...          NaN
# 32         NaN     NaN       5      18     14   NaN      14  ...          NaN
# 33         NaN     NaN       8      11      9   NaN     NaN  ...          NaN
# 34         NaN     NaN      15     NaN    NaN    18     NaN  ...          NaN
# 35         NaN     NaN      17     NaN     16    20       8  ...           18
# 36         NaN     NaN      19     NaN    NaN     6     NaN  ...          NaN
# 37         NaN     NaN     NaN       9    NaN   NaN     NaN  ...          NaN
# 38         NaN     NaN     NaN      12    NaN   NaN     NaN  ...          NaN
# 39         NaN     NaN     NaN      14     18   NaN     NaN  ...          NaN
# 40         NaN     NaN     NaN      20    NaN   NaN     NaN  ...          NaN
# 41         NaN     NaN     NaN     NaN    NaN    15      16  ...          NaN
# 42         NaN     NaN     NaN     NaN    NaN    16     NaN  ...          NaN
# 43         NaN     NaN     NaN     NaN    NaN    19     NaN  ...          NaN
# 44         NaN     NaN     NaN     NaN    NaN   NaN       6  ...          NaN
# 45         NaN     NaN     NaN     NaN    NaN   NaN      11  ...          NaN
# 46         NaN     NaN     NaN     NaN    NaN   NaN      20  ...          NaN
# 47         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...           20
# 48         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 49         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 50         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 51         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 52         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
# 53         NaN     NaN     NaN     NaN    NaN   NaN     NaN  ...          NaN
#
#    Boston Anaheim Denver Las Vegas San Diego Detroit Seattle San Antonio  \
# 0       3     NaN    NaN         3        10       1      18           8
# 1       1       1      1         1         1       2       1           1
# 2       6       4      6         2         9       8       4           4
# 3     NaN     NaN    NaN        10       NaN      13     NaN         NaN
# 4     NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 5      18     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 6       2       3      2        20         2       5       3           9
# 7      13     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 8      16     NaN    NaN        12       NaN       3     NaN          16
# 9      14      14     20        14       NaN       7     NaN           5
# 10     10       8      3         4         7      18       2           2
# 11      8      10      8       NaN         8     NaN      15          12
# 12      9       7     10       NaN         6     NaN      11           3
# 13    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 14      5       5      4         9         3       6       6          11
# 15      4       6      9       NaN         4     NaN       5         NaN
# 16     15       9     14         6        16      14       7          14
# 17     11       2      7         5         5       4      20           7
# 18    NaN      11     15        17        15      15       8         NaN
# 19    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 20    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 21    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 22    NaN      13    NaN        15        11     NaN     NaN           6
# 23    NaN      18    NaN       NaN       NaN     NaN     NaN         NaN
# 24    NaN     NaN    NaN       NaN        18     NaN     NaN         NaN
# 25    NaN      15    NaN       NaN       NaN     NaN     NaN         NaN
# 26    NaN     NaN    NaN       NaN        14     NaN     NaN         NaN
# 27    NaN     NaN    NaN       NaN       NaN      17     NaN         NaN
# 28     19      16    NaN         7       NaN      19      10         NaN
# 29    NaN     NaN    NaN       NaN       NaN       9     NaN         NaN
# 30     12     NaN     12       NaN        12     NaN      13         NaN
# 31      7     NaN      5       NaN        13     NaN      14         NaN
# 32    NaN     NaN    NaN       NaN       NaN     NaN     NaN          10
# 33    NaN     NaN    NaN        13       NaN      10     NaN          13
# 34    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 35    NaN      12     13        19       NaN      16       9          17
# 36    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 37    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 38    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 39    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 40    NaN     NaN    NaN        11       NaN      20     NaN         NaN
# 41    NaN      19     16        16       NaN     NaN      12         NaN
# 42    NaN      20    NaN       NaN        19     NaN     NaN         NaN
# 43    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 44     17     NaN    NaN         8       NaN     NaN     NaN          18
# 45    NaN     NaN     18       NaN       NaN      12      19          19
# 46    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
# 47    NaN      17     17       NaN       NaN      11      17         NaN
# 48     20     NaN     19       NaN        20     NaN      16         NaN
# 49    NaN     NaN     11       NaN       NaN     NaN     NaN         NaN
# 50    NaN     NaN    NaN        18       NaN     NaN     NaN         NaN
# 51    NaN     NaN    NaN       NaN        17     NaN     NaN          15
# 52    NaN     NaN    NaN       NaN       NaN     NaN     NaN          20
# 53    NaN     NaN    NaN       NaN       NaN     NaN     NaN         NaN
#
#    Orlando
# 0        3
# 1        1
# 2        2
# 3      NaN
# 4      NaN
# 5      NaN
# 6       10
# 7       15
# 8        5
# 9        8
# 10       4
# 11     NaN
# 12     NaN
# 13     NaN
# 14      12
# 15     NaN
# 16       6
# 17      13
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22       9
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28      17
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35      11
# 36      18
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41       7
# 42      14
# 43     NaN
# 44     NaN
# 45      20
# 46     NaN
# 47     NaN
# 48      16
# 49     NaN
# 50     NaN
# 51     NaN
# 52     NaN
# 53      19
#
# [54 rows x 22 columns]

# %%
#Call for the Top20 Songs from the US Chart

USChartURL = "https://shazam-core.p.rapidapi.com/v1/charts/country"

querystring = {"country_code":"US","limit":"50"}

headers = {
    'x-rapidapi-host': "shazam-core.p.rapidapi.com",
    'x-rapidapi-key': APIKey
    }

USChartResponse = requests.request("GET", USChartURL, headers=headers, params=querystring).json()

#USChartResponse

# Fill in the USTop20 Datframe with song/artist/ranking 

SongIndex = 0
while(SongIndex < 20):
    SongName = USChartResponse[SongIndex]['title']
    SongArtist = USChartResponse[SongIndex]['subtitle']
    #print(SongName, SongArtist, SongIndex)
    dfUSTop20 = dfUSTop20.append({"Song Name": SongName, "Artist": SongArtist, "Rank in Top US Chart": SongIndex+1}, ignore_index=True)
    SongIndex += 1

dfUSTop20
# Out:
#                                             Song Name  \
# 0                                Drink Before The War
# 1                                     I Lied (Part 1)
# 2                                  Ginseng Strip 2002
# 3                                      Here In Spirit
# 4                             Cold Heart (PNAU Remix)
# 5                                          Big Energy
# 6                                         Hrs and Hrs
# 7                                       Super Gremlin
# 8                                         I Look Good
# 9                                          Heat Waves
# 10                                    Fingers Crossed
# 11                                            abcdefu
# 12                                           I Hate U
# 13  Watercolor Eyes (From “Euphoria” An HBO Origin...
# 14                                        Better Days
# 15                                            Shivers
# 16                                  Ca Plane Pour Moi
# 17                                          Oh My God
# 18                                  THATS WHAT I WANT
# 19                                Never Tear Us Apart
#
#                               Artist Rank in USTop20 Chart  \
# 0                    Sinéad O'Connor                   NaN
# 1                       Scribz Riley                   NaN
# 2                          Yung Lean                   NaN
# 3                          Jim James                   NaN
# 4              Elton John & Dua Lipa                   NaN
# 5                              Latto                   NaN
# 6                          Muni Long                   NaN
# 7                        Kodak Black                   NaN
# 8                       O.T. Genasis                   NaN
# 9                      Glass Animals                   NaN
# 10              Lauren Spencer-Smith                   NaN
# 11                             GAYLE                   NaN
# 12                               SZA                   NaN
# 13                      Lana Del Rey                   NaN
# 14  NEIKED & Mae Muller Feat. Polo G                   NaN
# 15                        Ed Sheeran                   NaN
# 16                  Plastic Bertrand                   NaN
# 17                             Adele                   NaN
# 18                         Lil Nas X                   NaN
# 19                              INXS                   NaN
#
#     Rank in Top US Chart
# 0                    1.0
# 1                    2.0
# 2                    3.0
# 3                    4.0
# 4                    5.0
# 5                    6.0
# 6                    7.0
# 7                    8.0
# 8                    9.0
# 9                   10.0
# 10                  11.0
# 11                  12.0
# 12                  13.0
# 13                  14.0
# 14                  15.0
# 15                  16.0
# 16                  17.0
# 17                  18.0
# 18                  19.0
# 19                  20.0

# %%
# Set indexes on the US and City dataframe to Song Name and Artist 

dfCityTopSongs = dfCityTop20.set_index(['Song Name', 'Artist'])
dfUSTopSongs = dfUSTop20.set_index(['Song Name', 'Artist'])
dfUSTop20.head()
# Out:
#                  Song Name                 Artist Rank in USTop20 Chart  \
# 0     Drink Before The War        Sinéad O'Connor                   NaN
# 1          I Lied (Part 1)           Scribz Riley                   NaN
# 2       Ginseng Strip 2002              Yung Lean                   NaN
# 3           Here In Spirit              Jim James                   NaN
# 4  Cold Heart (PNAU Remix)  Elton John & Dua Lipa                   NaN
#
#    Rank in Top US Chart
# 0                   1.0
# 1                   2.0
# 2                   3.0
# 3                   4.0
# 4                   5.0

# %%
# Calculate the Importance Score for each Song
# 1. add up all rankings in each city (songs that didn't break into a city top chart is the number of cities + UnrankedSongChangedWeight)
# 2. Divide by number of cities 
# 3. Thus, most important songs have lowest Importance Score 

NumberofCities = maxCityLimit
NonRankedWeight = SongLimit + UnrankedSongChangedWeight
dfCityTopSongs['Sum of Rankings'] = dfCityTopSongs.sum(axis = 1)
dfCityTopSongs['Number of Cities without Rank'] = dfCityTopSongs.isna().sum(axis = 1)

# Importance Calculation applied to each row
def calculateImportance(row):
    row['Importance Score'] = (row['Sum of Rankings'] + (row['Number of Cities without Rank'] * NonRankedWeight))/NumberofCities
    return row
dfCityTopSongs = dfCityTopSongs.apply(calculateImportance, axis = 'columns')
dfCityTopSongs['Importance Score'] = dfCityTopSongs['Importance Score'].round(2)

#Clean up dataframe 
del(dfCityTopSongs['Sum of Rankings'])
del(dfCityTopSongs['Number of Cities without Rank'])

dfCityTopSongs.head()
# Out:
#                                                New York City  Los Angeles  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                     1.0          8.0
# Drink Before The War    Sinéad O'Connor                  2.0          1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa            3.0          7.0
# I Hate U                SZA                              4.0          NaN
# TO THE MOON             Jnr Choi                         5.0          NaN
#
#                                                Chicago  Houston  Atlanta  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley               2.0      2.0      1.0
# Drink Before The War    Sinéad O'Connor            1.0      1.0      2.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa      8.0     10.0      NaN
# I Hate U                SZA                       20.0      NaN     10.0
# TO THE MOON             Jnr Choi                   NaN      NaN      NaN
#
#                                                Dallas  Miami  Phoenix  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley              2.0    3.0     18.0
# Drink Before The War    Sinéad O'Connor           1.0    2.0      1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa    11.0    1.0      4.0
# I Hate U                SZA                      12.0    NaN      NaN
# TO THE MOON             Jnr Choi                  NaN    9.0      NaN
#
#                                                Riverside  Washington, D.C.  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                 7.0               1.0
# Drink Before The War    Sinéad O'Connor              1.0               2.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa        5.0              18.0
# I Hate U                SZA                          NaN              13.0
# TO THE MOON             Jnr Choi                     NaN               NaN
#
#                                                ...  Boston  Anaheim  Denver  \
# Song Name               Artist                 ...
# I Lied (Part 1)         Scribz Riley           ...     3.0      NaN     NaN
# Drink Before The War    Sinéad O'Connor        ...     1.0      1.0     1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa  ...     6.0      4.0     6.0
# I Hate U                SZA                    ...     NaN      NaN     NaN
# TO THE MOON             Jnr Choi               ...     NaN      NaN     NaN
#
#                                                Las Vegas  San Diego  Detroit  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                 3.0       10.0      1.0
# Drink Before The War    Sinéad O'Connor              1.0        1.0      2.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa        2.0        9.0      8.0
# I Hate U                SZA                         10.0        NaN     13.0
# TO THE MOON             Jnr Choi                     NaN        NaN      NaN
#
#                                                Seattle  San Antonio  Orlando  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley              18.0          8.0      3.0
# Drink Before The War    Sinéad O'Connor            1.0          1.0      1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa      4.0          4.0      2.0
# I Hate U                SZA                        NaN          NaN      NaN
# TO THE MOON             Jnr Choi                   NaN          NaN      NaN
#
#                                                Importance Score
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                       6.70
# Drink Before The War    Sinéad O'Connor                    1.30
# Cold Heart (PNAU Remix) Elton John & Dua Lipa              7.20
# I Hate U                SZA                               17.15
# TO THE MOON             Jnr Choi                          19.60
#
# [5 rows x 21 columns]

# %%
# Add in column counting how many cities the song broke Top 20 Charts
ColumnName = 'Number of Cities where Song Broke Top Chart'
Series = dfCityTopSongs.count(axis = 'columns')-1
Series = Series.rename(ColumnName)
dfCityTopSongs = pd.concat([dfCityTopSongs, Series], axis = 1)
dfCityTopSongs.head()
# Out:
#                                                New York City  Los Angeles  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                     1.0          8.0
# Drink Before The War    Sinéad O'Connor                  2.0          1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa            3.0          7.0
# I Hate U                SZA                              4.0          NaN
# TO THE MOON             Jnr Choi                         5.0          NaN
#
#                                                Chicago  Houston  Atlanta  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley               2.0      2.0      1.0
# Drink Before The War    Sinéad O'Connor            1.0      1.0      2.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa      8.0     10.0      NaN
# I Hate U                SZA                       20.0      NaN     10.0
# TO THE MOON             Jnr Choi                   NaN      NaN      NaN
#
#                                                Dallas  Miami  Phoenix  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley              2.0    3.0     18.0
# Drink Before The War    Sinéad O'Connor           1.0    2.0      1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa    11.0    1.0      4.0
# I Hate U                SZA                      12.0    NaN      NaN
# TO THE MOON             Jnr Choi                  NaN    9.0      NaN
#
#                                                Riverside  Washington, D.C.  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                 7.0               1.0
# Drink Before The War    Sinéad O'Connor              1.0               2.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa        5.0              18.0
# I Hate U                SZA                          NaN              13.0
# TO THE MOON             Jnr Choi                     NaN               NaN
#
#                                                ...  Anaheim  Denver  \
# Song Name               Artist                 ...
# I Lied (Part 1)         Scribz Riley           ...      NaN     NaN
# Drink Before The War    Sinéad O'Connor        ...      1.0     1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa  ...      4.0     6.0
# I Hate U                SZA                    ...      NaN     NaN
# TO THE MOON             Jnr Choi               ...      NaN     NaN
#
#                                                Las Vegas  San Diego  Detroit  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                 3.0       10.0      1.0
# Drink Before The War    Sinéad O'Connor              1.0        1.0      2.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa        2.0        9.0      8.0
# I Hate U                SZA                         10.0        NaN     13.0
# TO THE MOON             Jnr Choi                     NaN        NaN      NaN
#
#                                                Seattle  San Antonio  Orlando  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley              18.0          8.0      3.0
# Drink Before The War    Sinéad O'Connor            1.0          1.0      1.0
# Cold Heart (PNAU Remix) Elton John & Dua Lipa      4.0          4.0      2.0
# I Hate U                SZA                        NaN          NaN      NaN
# TO THE MOON             Jnr Choi                   NaN          NaN      NaN
#
#                                                Importance Score  \
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                       6.70
# Drink Before The War    Sinéad O'Connor                    1.30
# Cold Heart (PNAU Remix) Elton John & Dua Lipa              7.20
# I Hate U                SZA                               17.15
# TO THE MOON             Jnr Choi                          19.60
#
#                                                Number of Cities where Song Broke Top Chart
# Song Name               Artist
# I Lied (Part 1)         Scribz Riley                                                    18
# Drink Before The War    Sinéad O'Connor                                                 20
# Cold Heart (PNAU Remix) Elton John & Dua Lipa                                           19
# I Hate U                SZA                                                              8
# TO THE MOON             Jnr Choi                                                         2
#
# [5 rows x 22 columns]

# %%
# Concatenate the US and city dataframes into 1 dataframe
df = pd.concat([dfUSTopSongs, dfCityTopSongs], axis=1)
df.head()
# Out:
#                                                                         Rank in USTop20 Chart  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                        NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                              NaN
# Beautiful Lies                         Yung Bleu & Kehlani                                NaN
# Beggin'                                Måneskin                                           NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G                   NaN
#
#                                                                          Rank in Top US Chart  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                        NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                              NaN
# Beautiful Lies                         Yung Bleu & Kehlani                                NaN
# Beggin'                                Måneskin                                           NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G                  15.0
#
#                                                                          New York City  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                 NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                       6.0
# Beautiful Lies                         Yung Bleu & Kehlani                         NaN
# Beggin'                                Måneskin                                    NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G            NaN
#
#                                                                          Los Angeles  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                               NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                     NaN
# Beautiful Lies                         Yung Bleu & Kehlani                       NaN
# Beggin'                                Måneskin                                  NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G          NaN
#
#                                                                          Chicago  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                          19.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     12.0
#
#                                                                          Houston  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G      NaN
#
#                                                                          Atlanta  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                13.0
# Beautiful Lies                         Yung Bleu & Kehlani                  20.0
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G      NaN
#
#                                                                          Dallas  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                         17.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                NaN
# Beautiful Lies                         Yung Bleu & Kehlani                  NaN
# Beggin'                                Måneskin                             NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     NaN
#
#                                                                          Miami  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                         NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez              10.0
# Beautiful Lies                         Yung Bleu & Kehlani                 NaN
# Beggin'                                Måneskin                            NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G    NaN
#
#                                                                          Phoenix  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     13.0
#
#                                                                          ...  \
# Song Name                              Artist                            ...
# "R.A.P. Music" Album Untitled          Killer Mike                       ...
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez             ...
# Beautiful Lies                         Yung Bleu & Kehlani               ...
# Beggin'                                Måneskin                          ...
# Better Days                            NEIKED & Mae Muller Feat. Polo G  ...
#
#                                                                          Anaheim  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     16.0
#
#                                                                          Denver  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                          5.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                NaN
# Beautiful Lies                         Yung Bleu & Kehlani                  NaN
# Beggin'                                Måneskin                            19.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G     NaN
#
#                                                                          Las Vegas  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                             NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                   NaN
# Beautiful Lies                         Yung Bleu & Kehlani                    11.0
# Beggin'                                Måneskin                                NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G        7.0
#
#                                                                          San Diego  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                            13.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                   NaN
# Beautiful Lies                         Yung Bleu & Kehlani                     NaN
# Beggin'                                Måneskin                               20.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G        NaN
#
#                                                                          Detroit  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                  20.0
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     19.0
#
#                                                                          Seattle  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                          14.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                             16.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G     10.0
#
#                                                                          San Antonio  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                               NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                     NaN
# Beautiful Lies                         Yung Bleu & Kehlani                       NaN
# Beggin'                                Måneskin                                  NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G          NaN
#
#                                                                          Orlando  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                             16.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G     17.0
#
#                                                                          Importance Score  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                  17.90
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                        18.85
# Beautiful Lies                         Yung Bleu & Kehlani                          20.40
# Beggin'                                Måneskin                                     20.30
# Better Days                            NEIKED & Mae Muller Feat. Polo G             18.00
#
#                                                                          Number of Cities where Song Broke Top Chart
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                                                 7
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                                                       5
# Beautiful Lies                         Yung Bleu & Kehlani                                                         3
# Beggin'                                Måneskin                                                                    5
# Better Days                            NEIKED & Mae Muller Feat. Polo G                                            9
#
# [5 rows x 24 columns]

# %%
# Add Another column that shows if the song broke US Top 20 Chart
# df['Broke US Top Chart'] = np.where(pd.isna(df['Rank in Top US Chart']), False, True) is more concise but slow- results in highly fragmented dataframe

df = df.reset_index()
ColumnName = 'Broke US Top Chart'
Series = pd.Series(np.where(pd.isna(df['Rank in Top US Chart']), False, True))
Series = Series.rename(ColumnName)
df = pd.concat([df, Series], axis = 1)
df = df.set_index(['Song Name', 'Artist'])
df.head()
# Out:
#                                                                         Rank in USTop20 Chart  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                        NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                              NaN
# Beautiful Lies                         Yung Bleu & Kehlani                                NaN
# Beggin'                                Måneskin                                           NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G                   NaN
#
#                                                                          Rank in Top US Chart  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                        NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                              NaN
# Beautiful Lies                         Yung Bleu & Kehlani                                NaN
# Beggin'                                Måneskin                                           NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G                  15.0
#
#                                                                          New York City  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                 NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                       6.0
# Beautiful Lies                         Yung Bleu & Kehlani                         NaN
# Beggin'                                Måneskin                                    NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G            NaN
#
#                                                                          Los Angeles  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                               NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                     NaN
# Beautiful Lies                         Yung Bleu & Kehlani                       NaN
# Beggin'                                Måneskin                                  NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G          NaN
#
#                                                                          Chicago  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                          19.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     12.0
#
#                                                                          Houston  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G      NaN
#
#                                                                          Atlanta  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                13.0
# Beautiful Lies                         Yung Bleu & Kehlani                  20.0
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G      NaN
#
#                                                                          Dallas  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                         17.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                NaN
# Beautiful Lies                         Yung Bleu & Kehlani                  NaN
# Beggin'                                Måneskin                             NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     NaN
#
#                                                                          Miami  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                         NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez              10.0
# Beautiful Lies                         Yung Bleu & Kehlani                 NaN
# Beggin'                                Måneskin                            NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G    NaN
#
#                                                                          Phoenix  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     13.0
#
#                                                                          ...  \
# Song Name                              Artist                            ...
# "R.A.P. Music" Album Untitled          Killer Mike                       ...
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez             ...
# Beautiful Lies                         Yung Bleu & Kehlani               ...
# Beggin'                                Måneskin                          ...
# Better Days                            NEIKED & Mae Muller Feat. Polo G  ...
#
#                                                                          Denver  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                          5.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                NaN
# Beautiful Lies                         Yung Bleu & Kehlani                  NaN
# Beggin'                                Måneskin                            19.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G     NaN
#
#                                                                          Las Vegas  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                             NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                   NaN
# Beautiful Lies                         Yung Bleu & Kehlani                    11.0
# Beggin'                                Måneskin                                NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G        7.0
#
#                                                                          San Diego  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                            13.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                   NaN
# Beautiful Lies                         Yung Bleu & Kehlani                     NaN
# Beggin'                                Måneskin                               20.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G        NaN
#
#                                                                          Detroit  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                  20.0
# Beggin'                                Måneskin                              NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G     19.0
#
#                                                                          Seattle  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                          14.0
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                             16.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G     10.0
#
#                                                                          San Antonio  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                               NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                     NaN
# Beautiful Lies                         Yung Bleu & Kehlani                       NaN
# Beggin'                                Måneskin                                  NaN
# Better Days                            NEIKED & Mae Muller Feat. Polo G          NaN
#
#                                                                          Orlando  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                           NaN
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                 NaN
# Beautiful Lies                         Yung Bleu & Kehlani                   NaN
# Beggin'                                Måneskin                             16.0
# Better Days                            NEIKED & Mae Muller Feat. Polo G     17.0
#
#                                                                          Importance Score  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                  17.90
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                        18.85
# Beautiful Lies                         Yung Bleu & Kehlani                          20.40
# Beggin'                                Måneskin                                     20.30
# Better Days                            NEIKED & Mae Muller Feat. Polo G             18.00
#
#                                                                          Number of Cities where Song Broke Top Chart  \
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                                                 7
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                                                       5
# Beautiful Lies                         Yung Bleu & Kehlani                                                         3
# Beggin'                                Måneskin                                                                    5
# Better Days                            NEIKED & Mae Muller Feat. Polo G                                            9
#
#                                                                          Broke US Top Chart
# Song Name                              Artist
# "R.A.P. Music" Album Untitled          Killer Mike                                    False
# Ameno Amapiano Remix (You Wanna Bamba) Goya Menor & Nektunez                          False
# Beautiful Lies                         Yung Bleu & Kehlani                            False
# Beggin'                                Måneskin                                       False
# Better Days                            NEIKED & Mae Muller Feat. Polo G                True
#
# [5 rows x 25 columns]

# %%
# Reorder columns and export merged dataframe as csv

filename = 'TopSongsinUSandCity.csv'
path = pathtoDFolder + filename
columns = df.columns.tolist()
columns = columns[0:1] + columns[-3:] + columns[1:]
del columns[-3:]
df = df[columns]

TempImportanceScore = df['Importance Score']
df = df.drop(columns=['Importance Score'])
df.insert(loc=0, column='Importance Score', value=TempImportanceScore)

#Reorder columns and export final, merged dataframe as CSV
df = df.reset_index()
df = df.set_index('Importance Score').sort_index(axis = 0, ascending = True)
df.to_csv(path)

# %%
# Create a new dataframe with only important songs (songs in this dataframe that has not broken the US Top Chart yet)
# Important Songs are songs that have broken into at least one city's Top Chart but has not broken into the US Top Chart
# delete the column 'Rank in USTop20 Chart

filename = 'MostImportantSongsinUS.csv'
path = pathtoDFolder + filename

important_df = df[(df['Number of Cities where Song Broke Top Chart']>0) & (df['Broke US Top Chart'] == False)]
important_df = important_df.reset_index()
important_df = (important_df
                    .set_index(['Importance Score'])
                    .sort_index(axis = 0, ascending = True))
important_df = important_df.drop(columns = ['Rank in Top US Chart'])

#Export to CSV 
important_df.to_csv(path)

# %%
# Create another column in dataframe that lists all the cities that each song broke into its top charts

#Set index to Song name and artist and keep only columns of cities in new dataframe 
df = important_df.reset_index()
df = df.set_index(['Song Name', 'Artist']).head()
df_new = df.loc[:, 'New York City':'Orlando']

# Rotate columns and axis to make the songs/artists keys in the dictionary 
df_new = df_new.T

# Total dataframe in dictionary form 
# keys = song/artist tuple 
# Value = dictionary where key = column name and value = element from dataframe
dict = df_new.to_dict()
dict

#Populate a new dictionary where its keys = songs/artist and values = all cities that the song is in its top20 chart
SongCitiesDict = {}
ColumnName = 'List of Cities where Song Broke Top Chart'

# Extract song/artist name 
for Song in dict:
    CityList = []
    CityDict = dict.get(Song)
    for City in CityDict:
        if pd.isna(CityDict.get(City)) == False:
            CityList.append(City)
    SongCitiesDict[Song] = CityList
    
    #Turn CityList into a string to insert into the original df dataframe 
    CityList = ', '.join([str(city) for city in CityList])
    df.loc[Song, ColumnName] = CityList
df.head()
# Out:
#                                                         Importance Score  \
# Song Name                     Artist
# Pepas                         Farruko                              15.75
# Peru                          Fireboy DML & Ed Sheeran             17.50
# Scorpio                       Moneybagg Yo                         17.80
# "R.A.P. Music" Album Untitled Killer Mike                          17.90
# Pressure                      Ari Lennox                           18.30
#
#                                                        Rank in USTop20 Chart  \
# Song Name                     Artist
# Pepas                         Farruko                                    NaN
# Peru                          Fireboy DML & Ed Sheeran                   NaN
# Scorpio                       Moneybagg Yo                               NaN
# "R.A.P. Music" Album Untitled Killer Mike                                NaN
# Pressure                      Ari Lennox                                 NaN
#
#                                                         Number of Cities where Song Broke Top Chart  \
# Song Name                     Artist
# Pepas                         Farruko                                                            11
# Peru                          Fireboy DML & Ed Sheeran                                            7
# Scorpio                       Moneybagg Yo                                                        7
# "R.A.P. Music" Album Untitled Killer Mike                                                         7
# Pressure                      Ari Lennox                                                          6
#
#                                                         Broke US Top Chart  \
# Song Name                     Artist
# Pepas                         Farruko                                False
# Peru                          Fireboy DML & Ed Sheeran               False
# Scorpio                       Moneybagg Yo                           False
# "R.A.P. Music" Album Untitled Killer Mike                            False
# Pressure                      Ari Lennox                             False
#
#                                                         New York City  \
# Song Name                     Artist
# Pepas                         Farruko                             NaN
# Peru                          Fireboy DML & Ed Sheeran            8.0
# Scorpio                       Moneybagg Yo                        NaN
# "R.A.P. Music" Album Untitled Killer Mike                         NaN
# Pressure                      Ari Lennox                          NaN
#
#                                                         Los Angeles  Chicago  \
# Song Name                     Artist
# Pepas                         Farruko                          15.0      NaN
# Peru                          Fireboy DML & Ed Sheeran          NaN      NaN
# Scorpio                       Moneybagg Yo                      NaN      NaN
# "R.A.P. Music" Album Untitled Killer Mike                       NaN     19.0
# Pressure                      Ari Lennox                        NaN     14.0
#
#                                                         Houston  Atlanta  \
# Song Name                     Artist
# Pepas                         Farruko                      12.0      NaN
# Peru                          Fireboy DML & Ed Sheeran      NaN     16.0
# Scorpio                       Moneybagg Yo                  8.0     11.0
# "R.A.P. Music" Album Untitled Killer Mike                   NaN      NaN
# Pressure                      Ari Lennox                   16.0      6.0
#
#                                                         Dallas  ...  Boston  \
# Song Name                     Artist                            ...
# Pepas                         Farruko                     20.0  ...     NaN
# Peru                          Fireboy DML & Ed Sheeran     NaN  ...    13.0
# Scorpio                       Moneybagg Yo                 9.0  ...     NaN
# "R.A.P. Music" Album Untitled Killer Mike                 17.0  ...     7.0
# Pressure                      Ari Lennox                   NaN  ...     NaN
#
#                                                         Anaheim  Denver  \
# Song Name                     Artist
# Pepas                         Farruko                      13.0     NaN
# Peru                          Fireboy DML & Ed Sheeran      NaN     NaN
# Scorpio                       Moneybagg Yo                  NaN     NaN
# "R.A.P. Music" Album Untitled Killer Mike                   NaN     5.0
# Pressure                      Ari Lennox                    NaN     NaN
#
#                                                         Las Vegas  San Diego  \
# Song Name                     Artist
# Pepas                         Farruko                        15.0       11.0
# Peru                          Fireboy DML & Ed Sheeran        NaN        NaN
# Scorpio                       Moneybagg Yo                   13.0        NaN
# "R.A.P. Music" Album Untitled Killer Mike                     NaN       13.0
# Pressure                      Ari Lennox                      NaN        NaN
#
#                                                         Detroit  Seattle  \
# Song Name                     Artist
# Pepas                         Farruko                       NaN      NaN
# Peru                          Fireboy DML & Ed Sheeran      NaN      NaN
# Scorpio                       Moneybagg Yo                 10.0      NaN
# "R.A.P. Music" Album Untitled Killer Mike                   NaN     14.0
# Pressure                      Ari Lennox                    9.0      NaN
#
#                                                         San Antonio  Orlando  \
# Song Name                     Artist
# Pepas                         Farruko                           6.0      9.0
# Peru                          Fireboy DML & Ed Sheeran          NaN     15.0
# Scorpio                       Moneybagg Yo                     13.0      NaN
# "R.A.P. Music" Album Untitled Killer Mike                       NaN      NaN
# Pressure                      Ari Lennox                        NaN      NaN
#
#                                                                 List of Cities where Song Broke Top Chart
# Song Name                     Artist
# Pepas                         Farruko                   Los Angeles, Houston, Dallas, Miami, Phoenix, ...
# Peru                          Fireboy DML & Ed Sheeran  New York City, Atlanta, Miami, Washington, D.C...
# Scorpio                       Moneybagg Yo              Houston, Atlanta, Dallas, Washington, D.C., La...
# "R.A.P. Music" Album Untitled Killer Mike               Chicago, Dallas, Washington, D.C., Boston, Den...
# Pressure                      Ari Lennox                Chicago, Houston, Atlanta, Washington, D.C., P...
#
# [5 rows x 25 columns]

# %%
#Reorder Columns
columns = df.columns.tolist()
columns = columns[0:2]+ columns[-1:] + columns[2:]
del columns[-1:]
df = df[columns]
df
# Out:
#                                                         Importance Score  \
# Song Name                     Artist
# Pepas                         Farruko                              15.75
# Peru                          Fireboy DML & Ed Sheeran             17.50
# Scorpio                       Moneybagg Yo                         17.80
# "R.A.P. Music" Album Untitled Killer Mike                          17.90
# Pressure                      Ari Lennox                           18.30
#
#                                                        Rank in USTop20 Chart  \
# Song Name                     Artist
# Pepas                         Farruko                                    NaN
# Peru                          Fireboy DML & Ed Sheeran                   NaN
# Scorpio                       Moneybagg Yo                               NaN
# "R.A.P. Music" Album Untitled Killer Mike                                NaN
# Pressure                      Ari Lennox                                 NaN
#
#                                                                 List of Cities where Song Broke Top Chart  \
# Song Name                     Artist
# Pepas                         Farruko                   Los Angeles, Houston, Dallas, Miami, Phoenix, ...
# Peru                          Fireboy DML & Ed Sheeran  New York City, Atlanta, Miami, Washington, D.C...
# Scorpio                       Moneybagg Yo              Houston, Atlanta, Dallas, Washington, D.C., La...
# "R.A.P. Music" Album Untitled Killer Mike               Chicago, Dallas, Washington, D.C., Boston, Den...
# Pressure                      Ari Lennox                Chicago, Houston, Atlanta, Washington, D.C., P...
#
#                                                         Number of Cities where Song Broke Top Chart  \
# Song Name                     Artist
# Pepas                         Farruko                                                            11
# Peru                          Fireboy DML & Ed Sheeran                                            7
# Scorpio                       Moneybagg Yo                                                        7
# "R.A.P. Music" Album Untitled Killer Mike                                                         7
# Pressure                      Ari Lennox                                                          6
#
#                                                         Broke US Top Chart  \
# Song Name                     Artist
# Pepas                         Farruko                                False
# Peru                          Fireboy DML & Ed Sheeran               False
# Scorpio                       Moneybagg Yo                           False
# "R.A.P. Music" Album Untitled Killer Mike                            False
# Pressure                      Ari Lennox                             False
#
#                                                         New York City  \
# Song Name                     Artist
# Pepas                         Farruko                             NaN
# Peru                          Fireboy DML & Ed Sheeran            8.0
# Scorpio                       Moneybagg Yo                        NaN
# "R.A.P. Music" Album Untitled Killer Mike                         NaN
# Pressure                      Ari Lennox                          NaN
#
#                                                         Los Angeles  Chicago  \
# Song Name                     Artist
# Pepas                         Farruko                          15.0      NaN
# Peru                          Fireboy DML & Ed Sheeran          NaN      NaN
# Scorpio                       Moneybagg Yo                      NaN      NaN
# "R.A.P. Music" Album Untitled Killer Mike                       NaN     19.0
# Pressure                      Ari Lennox                        NaN     14.0
#
#                                                         Houston  Atlanta  ...  \
# Song Name                     Artist                                      ...
# Pepas                         Farruko                      12.0      NaN  ...
# Peru                          Fireboy DML & Ed Sheeran      NaN     16.0  ...
# Scorpio                       Moneybagg Yo                  8.0     11.0  ...
# "R.A.P. Music" Album Untitled Killer Mike                   NaN      NaN  ...
# Pressure                      Ari Lennox                   16.0      6.0  ...
#
#                                                         Philadelphia  Boston  \
# Song Name                     Artist
# Pepas                         Farruko                            NaN     NaN
# Peru                          Fireboy DML & Ed Sheeran           6.0    13.0
# Scorpio                       Moneybagg Yo                       NaN     NaN
# "R.A.P. Music" Album Untitled Killer Mike                        NaN     7.0
# Pressure                      Ari Lennox                        10.0     NaN
#
#                                                         Anaheim  Denver  \
# Song Name                     Artist
# Pepas                         Farruko                      13.0     NaN
# Peru                          Fireboy DML & Ed Sheeran      NaN     NaN
# Scorpio                       Moneybagg Yo                  NaN     NaN
# "R.A.P. Music" Album Untitled Killer Mike                   NaN     5.0
# Pressure                      Ari Lennox                    NaN     NaN
#
#                                                         Las Vegas  San Diego  \
# Song Name                     Artist
# Pepas                         Farruko                        15.0       11.0
# Peru                          Fireboy DML & Ed Sheeran        NaN        NaN
# Scorpio                       Moneybagg Yo                   13.0        NaN
# "R.A.P. Music" Album Untitled Killer Mike                     NaN       13.0
# Pressure                      Ari Lennox                      NaN        NaN
#
#                                                         Detroit  Seattle  \
# Song Name                     Artist
# Pepas                         Farruko                       NaN      NaN
# Peru                          Fireboy DML & Ed Sheeran      NaN      NaN
# Scorpio                       Moneybagg Yo                 10.0      NaN
# "R.A.P. Music" Album Untitled Killer Mike                   NaN     14.0
# Pressure                      Ari Lennox                    9.0      NaN
#
#                                                         San Antonio  Orlando
# Song Name                     Artist
# Pepas                         Farruko                           6.0      9.0
# Peru                          Fireboy DML & Ed Sheeran          NaN     15.0
# Scorpio                       Moneybagg Yo                     13.0      NaN
# "R.A.P. Music" Album Untitled Killer Mike                       NaN      NaN
# Pressure                      Ari Lennox                        NaN      NaN
#
# [5 rows x 25 columns]

# %%
# CSV deliverable exported to CSV 
path = '/Users/zacharywong/github/zacharywong2023/Shazam_ETL_Pipeline_Python/Top5ImportantSongs.csv'
df = df.reset_index()
df.to_csv(path, index = False)

# %%
# Update Google Spreadsheet 

df = df.fillna('')
spreadsheet_id = '1WYvfPFW6n2hOCZ-2_pTT0hjJOj5vGHbwjLnjzDqXhSM'
spreadsheet_name = 'Top 5 Important Songs of the Day'
sh = gc.open_by_key(spreadsheet_id)
worksheet = sh.get_worksheet(0)
worksheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1WYvfPFW6n2hOCZ-2_pTT0hjJOj5vGHbwjLnjzDqXhSM',
#  'updatedRange': "'Top 5 Important Songs of the Day'!A1:AA6",
#  'updatedRows': 6,
#  'updatedColumns': 27,
#  'updatedCells': 162}

# %%
# Send email with deliverable file attached if user chooses not to pause emails

# read in value for paused email
PauseEmailCellLocation = 'B12'
EmailPause = readinValue(spreadsheet_id, PauseEmailCellLocation)

#If not paused, send email
if (EmailPause == 'N'):
    
    # assign emails, passwords, and csv file to variables
    subject = 'Top 5 Most Important Songs of the Day'
    text = "Hi, \n\nAttached is today's CSV attachment with the Top 5 Most Important Songs of the Day you should look out for! \nFor your convenience, here is the link to the auto-generated Google Spreadsheet with dynamic tables/graphs: \nhttps://docs.google.com/spreadsheets/d/1WYvfPFW6n2hOCZ-2_pTT0hjJOj5vGHbwjLnjzDqXhSM/edit?usp=sharing \n\nBest Regards, \nZachary Wong"
    sender_email = "zacharywongdatascience"
    receiver_email = 'zachary.j.wong.23@dartmouth.edu'
    password = ''
    pathtoPassword = '/Users/zacharywong/Documents/ApplicationPassword-Secret/ApplicationPassword.txt'
    with open (pathtoPassword, 'r') as file:
        password = file.read()
    filename = 'Top5ImportantSongs-' + str(date.today()) +'.csv'
    filepath = '/Users/zacharywong/github/zacharywong2023/ShazamETLPipeline/Top5ImportantSongs.csv'

    # Attach each component with respective MIMEMultipart 
    msg = MIMEMultipart()
    msg ["From"] = sender_email
    msg ["To"] = receiver_email
    msg ["Subject"] = subject
    msg.attach(MIMEText(text, "plain"))
    with open (filepath, 'rb') as file:
        msg.attach(MIMEApplication(file.read(), Name=filename))
    
    # attach file metadata
    msg['Content Disposition'] = "attachment; filename=Top5ImportantSongs"
    
    # send email through SSL 
    content = msg.as_string()
    context = ssl.create_default_context()
    with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, content)
